# %%
import numpy as np

# %%
myarray = np.arange(1,150,100000)
mylist = list(range(100000))
# %time for _ in range(10): myarray2 = myarray ** 2
myarray
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([1])
